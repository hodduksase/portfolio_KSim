# %%
# 기본 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 기본 테마 설정
# https://coldbrown.co.kr/2023/07/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%8B%A4%EC%A0%84%ED%8E%B8-08-seaborn-sns-set%EC%9D%84-%ED%86%B5%ED%95%B4-%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# %%
# 데이터 불러오기

# 빈집비율과_면적당_의료기관_수_연도문자형

df_area = pd.read_csv('data/빈집비율과_면적당_의료기관_수_연도문자형.csv', encoding='utf-8')
df_area
# Out:
#          시도  면적당_의료기관 수  빈집비율    연도
# 0   강원특별자치도        0.07  12.1  2022
# 1   강원특별자치도        0.07  12.2  2023
# 2       경기도        1.10   5.6  2022
# 3       경기도        1.10   5.9  2023
# 4      경상남도        0.24  10.3  2022
# 5      경상남도        0.24  10.1  2023
# 6      경상북도        0.10  11.5  2022
# 7      경상북도        0.10  11.7  2023
# 8     광주광역시        2.73   7.1  2022
# 9     광주광역시        2.73   7.2  2023
# 10    대구광역시        3.20   5.2  2022
# 11    대구광역시        3.20   6.5  2023
# 12    대전광역시        3.04   5.1  2022
# 13    대전광역시        3.04   4.9  2023
# 14    부산광역시        4.86   8.4  2022
# 15    부산광역시        4.86   8.6  2023
# 16    서울특별시       21.77   3.2  2022
# 17    서울특별시       21.77   3.4  2023
# 18  세종특별자치시        0.66   8.2  2022
# 19  세종특별자치시        0.66   8.5  2023
# 20    울산광역시        0.86   7.4  2022
# 21    울산광역시        0.86   7.6  2023
# 22    인천광역시        2.28   6.6  2022
# 23    인천광역시        2.28   7.5  2023
# 24     전라남도        0.11  14.5  2022
# ...

# %%
# 연도 컬럼을 문자형으로 변환
df_area['연도'] = df_area['연도'].astype(str)

# 확인
print(df_area.dtypes)
# Out:
# 시도             object
# 면적당_의료기관 수    float64
# 빈집비율          float64
# 연도             object
# dtype: object

# %%
df_area.to_csv('data/process_data/빈집비율과_면적당_의료기관수_2022_2023.csv', index=False, encoding='utf-8-sig')
